# %%
from data_pipeline import *
trainData = POEMS("../Poetry_Dataset/Poetry_para.txt")
x, y = trainData.generateBatch()
x
# Out:
# array([   2,  146, 4064,  652,  169, 1488,   85, 1136,    0,   87,  945,
#         828, 2037,  345,  440,   70,    1,  372,   18,  141,  425,  851,
#         260,   65,    0,  147,   25,  116, 2589, 1587, 1854, 2103,    1,
#         527,  585,   23,  122,   69,  149,   44,    0,  433, 1088,   10,
#         126,   60,   39, 1528,    1, 2527,  239,    9,  115,   45,   44,
#         911,    0, 3042, 3079,    4,   56,   54,   11,   15,    1,    3,
#        9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832,
#        9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832,
#        9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832, 9832,
#        9832], dtype=int32)
