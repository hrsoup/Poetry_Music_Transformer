# %%
from data_pipeline import *
trainData = POEMS("../Poetry_Dataset/Poetry_para.txt")
data_train_files = trainData.poemVector
x, y = get_data(hparams.n_time, data_train_files,'train', 0, 'poetry', 9833)
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-a2cab299a13f> in <module>
#       2 trainData = POEMS("../Poetry_Dataset/Poetry_para.txt")
#       3 data_train_files = trainData.poemVector
# ----> 4 x, y = get_data(hparams.n_time, data_train_files,'train', 0, 'poetry', 9833)
#       5 x
#
# TypeError: cannot unpack non-iterable NoneType object
