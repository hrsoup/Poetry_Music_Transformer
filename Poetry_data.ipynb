# %%
import Poetry_Class
trainData = Poetry_Class.POEMS("../Poetry_Dataset/Poetry_para.txt")
x, y = trainData.generateBatch()
x
# Out:
# array([   2, 1923, 1211,    5,   84,    7,  225,  164,    0,  612,  886,
#         106,   21,   27,   39,   79,    1,  317,  917,  551], dtype=int32)
