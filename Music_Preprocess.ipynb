# %% [markdown]
# ### Event Extract from Midi File

# %%
import mido
import numpy as np


def get_eventlist(data_file):
    ON = 1
    OFF = 0
    CC = 2

    midi = mido.MidiFile(data_file)

    current_time = 0
    eventlist = []
    cc = False
    for msg in midi: 
        current_time += msg.time

         # NOTE ON CASE
        if msg.type is 'note_on' and msg.velocity > 0:
            event = [current_time, ON, msg.note, msg.velocity]
            eventlist.append(event)

         # NOTE OFF CASE        
        elif msg.type is 'note_off' or (msg.type is 'note_on' and msg.velocity == 0):
            event = [current_time, OFF, msg.note, msg.velocity]
            eventlist.append(event)
            
#         if msg.type is 'control_change':
            
#             if msg.control != 64:
#                 continue
            
#             if cc == False and msg.value > 0:
#                 cc = True
#                 event = [current_time, CC, 0, 1]
#                 eventlist.append(event)
                
#             elif cc == True and msg.value == 0:
#                 cc = False
#                 event = [current_time, CC, 0, 0]
#                 eventlist.append(event)
                
    eventlist = np.array(eventlist)
    return eventlist

# %% [markdown]
# ### Midifile to EventListfile

# %%
from tqdm import tqdm_notebook as tqdm
import os
from os import listdir
from os.path import isfile, join

old_dir = '../Music_Dataset'
dataset_dir = '../Music_dataset_after_preprocess'

if not os.path.exists(dataset_dir):
    os.makedirs(dataset_dir)
    
if not os.path.exists(str(dataset_dir)+'/train'):
    os.makedirs(str(dataset_dir)+'/train')

if not os.path.exists(str(dataset_dir)+'/test'):
    os.makedirs(str(dataset_dir)+'/test')
    
data_train_files = []
data_train_files += [join('../Music_Dataset/train/', f)for f in listdir('../Music_Dataset/train') if isfile(join('../Music_Dataset/train', f)) if 'midi' in f]
for i in tqdm(range(len(data_train_files))):
    eventlist = get_eventlist(data_train_files[i]) 
#     print(eventlist)
    save_file = dataset_dir + '/train/' + str(i)
    data = {'eventlist': eventlist}
    np.savez(save_file, **data, allow_pickle=False)
  

data_test_files = []  
data_test_files += [join('../Music_Dataset/test/', f)for f in listdir('../Music_Dataset/test') if isfile(join('../Music_Dataset/test', f)) if 'midi' in f]
for i in tqdm(range(len(data_test_files))):
    eventlist = get_eventlist(data_test_files[i])    
    save_file = dataset_dir + '/test/' + str(i)
    data = {'eventlist': eventlist}
    np.savez(save_file, **data, allow_pickle=False)
# Out:
#   0%|          | 0/967 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b89bdd5307f8> in <module>
#      19 data_train_files += [join('../Music_Dataset/train/', f)for f in listdir('../Music_Dataset/train') if isfile(join('../Music_Dataset/train', f)) if 'midi' in f]
#      20 for i in tqdm(range(len(data_train_files))):
# ---> 21     eventlist = get_eventlist(data_train_files[i])
#      22 #     print(eventlist)
#      23     save_file = dataset_dir + '/train/' + str(i)
#
# <ipython-input-1-a4dece0cbf54> in get_eventlist(data_file)
#      13     eventlist = []
#      14     cc = False
# ---> 15     for msg in midi:
#      16         current_time += msg.time
#      17
#
# ~/anaconda3/envs/hrsoup/lib/python3.7/site-packages/mido/midifiles/midifiles.py in __iter__(self)
#     374
#     375         tempo = DEFAULT_TEMPO
# --> 376         for msg in merge_tracks(self.tracks):
#     377             # Convert message time from absolute time
#     378             # in ticks to relative time in seconds.
#
# ~/anaconda3/envs/hrsoup/lib/python3.7/site-packages/mido/midifiles/tracks.py in merge_tracks(tracks)
#     106     messages.sort(key=lambda msg: msg.time)
#     107
# --> 108     return MidiTrack(fix_end_of_track(_to_reltime(messages)))
#
# ~/anaconda3/envs/hrsoup/lib/python3.7/site-packages/mido/midifiles/tracks.py in fix_end_of_track(messages)
#      80     accum = 0
#      81
# ---> 82     for msg in messages:
#      83         if msg.type == 'end_of_track':
#      84             accum += msg.time
#
# ~/anaconda3/envs/hrsoup/lib/python3.7/site-packages/mido/midifiles/tracks.py in _to_reltime(messages)
#      68     for msg in messages:
#      69         delta = msg.time - now
# ---> 70         yield msg.copy(time=delta)
#      71         now = msg.time
#      72
#
# ~/anaconda3/envs/hrsoup/lib/python3.7/site-packages/mido/messages/messages.py in copy(self, **overrides)
#     111         msgdict.update(overrides)
#     112         check_msgdict(msgdict)
# --> 113         return self.__class__(**msgdict)
#     114
#     115     @classmethod
#
# ~/anaconda3/envs/hrsoup/lib/python3.7/site-packages/mido/messages/messages.py in __init__(self, type, **args)
#      86         if type == 'sysex':
#      87             msgdict['data'] = SysexData(convert_py2_bytes(msgdict['data']))
# ---> 88         check_msgdict(msgdict)
#      89         vars(self).update(msgdict)
#      90
#
# ~/anaconda3/envs/hrsoup/lib/python3.7/site-packages/mido/messages/checks.py in check_msgdict(msgdict)
#      97                 '{} message has no attribute {}'.format(spec['type'], name))
#      98
# ---> 99         check_value(name, value)
#
# ~/anaconda3/envs/hrsoup/lib/python3.7/site-packages/mido/messages/checks.py in check_value(name, value)
#      84
#      85 def check_value(name, value):
# ---> 86     _CHECKS[name](value)
#      87
#      88
#
# ~/anaconda3/envs/hrsoup/lib/python3.7/site-packages/mido/messages/checks.py in check_channel(channel)
#      13     if not isinstance(channel, Integral):
#      14         raise TypeError('channel must be int')
# ---> 15     elif not 0 <= channel <= 15:
#      16         raise ValueError('channel must be in range 0..15')
#      17
#
# KeyboardInterrupt:
